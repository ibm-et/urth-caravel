# %%
# %%html
# <link rel='import' href='urth_components/urth-caravel/urth-caravel-slice.html' is='urth-core-import'>
# <link rel='import' href='urth_components/paper-slider/paper-slider.html' is='urth-core-import' package='PolymerElements/paper-slider'>
# Out:
# <link rel='import' href='urth_components/urth-caravel/urth-caravel-slice.html' is='urth-core-import'>
# <link rel='import' href='urth_components/paper-slider/paper-slider.html' is='urth-core-import' package='PolymerElements/paper-slider'>

# %% [markdown]
# Load caravel line chart with JSON embedded as child text

# %%
# %%html
# <urth-caravel-slice id="slice1">
# {
#  "json_endpoint": "/caravel/explore/table/2/?slice_name=Growth+Rate&row_limit=50000&metric=sum__SP_POP_TOTL&show_bubbles=y&entity=country_code&groupby=country_name&secondary_metric=sum__SP_POP_TOTL&viz_type=line&since=1960-01-01&json=true&until=2014-01-01&datasource_id=1&metrics=sum__SP_POP_TOTL&markup_type=markdown&country_fieldtype=cca3&granularity=year&slice_id=5&num_period_compare=10&datasource_type=table&compare_lag=10&limit=25&datasource_name=birth_names&where=&compare_suffix=o10Y",
#  "csv_endpoint": "/caravel/explore/table/2/?slice_name=Growth+Rate&row_limit=50000&metric=sum__SP_POP_TOTL&show_bubbles=y&entity=country_code&groupby=country_name&secondary_metric=sum__SP_POP_TOTL&viz_type=line&since=1960-01-01&csv=true&until=2014-01-01&datasource_id=1&metrics=sum__SP_POP_TOTL&markup_type=markdown&country_fieldtype=cca3&granularity=year&slice_id=5&num_period_compare=10&datasource_type=table&compare_lag=10&limit=25&datasource_name=birth_names&where=&compare_suffix=o10Y",
#  "standalone_endpoint": "/caravel/explore/table/2/?slice_name=Growth+Rate&row_limit=50000&metric=sum__SP_POP_TOTL&show_bubbles=y&entity=country_code&groupby=country_name&secondary_metric=sum__SP_POP_TOTL&viz_type=line&since=1960-01-01&until=2014-01-01&datasource_id=1&metrics=sum__SP_POP_TOTL&markup_type=markdown&country_fieldtype=cca3&granularity=year&slice_id=5&standalone=true&num_period_compare=10&datasource_type=table&compare_lag=10&limit=25&datasource_name=birth_names&where=&compare_suffix=o10Y",
#  "token": "token_034b4b7e",
#  "viz_name": "line",
#  "form_data": {
#   "slice_name": "Growth Rate",
#   "y_axis_zero": false,
#   "resample_fillmethod": "",
#   "line_interpolation": "linear",
#   "show_legend": true,
#   "granularity_sqla": "year",
#   "flt_op_5": "in",
#   "flt_op_4": "in",
#   "flt_op_7": "in",
#   "flt_op_6": "in",
#   "flt_op_1": "in",
#   "flt_op_0": "in",
#   "flt_op_3": "in",
#   "flt_op_2": "in",
#   "flt_op_9": "in",
#   "flt_op_8": "in",
#   "json": "false",
#   "until": "2014-01-01",
#   "y_axis_format": ".3s",
#   "slice_id": "5",
#   "resample_how": "",
#   "flt_col_6": "country_code",
#   "rich_tooltip": true,
#   "limit": "25",
#   "x_axis_format": "smart_date",
#   "async": null,
#   "where": "",
#   "force": null,
#   "show_brush": false,
#   "resample_rule": "",
#   "rolling_type": "None",
#   "viz_type": "line",
#   "since": "1960-01-01",
#   "time_compare": "",
#   "collapsed_fieldsets": null,
#   "rolling_periods": null,
#   "x_axis_showminmax": true,
#   "metrics": [
#    "sum__SP_POP_TOTL"
#   ],
#   "flt_eq_8": "",
#   "flt_eq_9": "",
#   "flt_eq_6": "",
#   "flt_eq_7": "",
#   "flt_eq_4": "",
#   "flt_eq_5": "",
#   "flt_eq_2": "",
#   "flt_eq_3": "",
#   "flt_eq_0": "",
#   "flt_eq_1": "",
#   "flt_col_1": "country_code",
#   "flt_col_0": "country_code",
#   "flt_col_3": "country_code",
#   "flt_col_2": "country_code",
#   "flt_col_5": "country_code",
#   "flt_col_4": "country_code",
#   "flt_col_7": "country_code",
#   "standalone": null,
#   "flt_col_9": "country_code",
#   "flt_col_8": "country_code",
#   "num_period_compare": 10,
#   "previous_viz_type": "line",
#   "having": "",
#   "y_log_scale": false,
#   "contribution": false,
#   "extra_filters": null,
#   "groupby": [
#    "country_name"
#   ]
#  }
# }
# </urth-caravel-slice>
# Out:
# <urth-caravel-slice id="slice1">
# {
#  "json_endpoint": "/caravel/explore/table/2/?slice_name=Growth+Rate&row_limit=50000&metric=sum__SP_POP_TOTL&show_bubbles=y&entity=country_code&groupby=country_name&secondary_metric=sum__SP_POP_TOTL&viz_type=line&since=1960-01-01&json=true&until=2014-01-01&datasource_id=1&metrics=sum__SP_POP_TOTL&markup_type=markdown&country_fieldtype=cca3&granularity=year&slice_id=5&num_period_compare=10&datasource_type=table&compare_lag=10&limit=25&datasource_name=birth_names&where=&compare_suffix=o10Y",
# ...

# %% [markdown]
# Load caravel line chart with JSON embedded as child text

# %%
# %%html
# <urth-caravel-slice id="slice1">
# {"json_endpoint":"\/caravel\/explore\/table\/3\/?force=false&slice_name=Genders+by+State&row_limit=50000&show_legend=y&show_legend=false&groupby=state&granularity_sqla=ds&flt_op_1=not+in&flt_op_0=in&viz_type=dist_bar&since=100+years+ago&json=true&until=now&collapsed_fieldsets=&datasource_id=3&y_axis_format=.3s&metrics=sum__sum_girls&metrics=sum__sum_boys&flt_eq_0=&flt_eq_1=other&flt_col_1=state&flt_col_0=gender&slice_id=16&previous_viz_type=dist_bar&having=&datasource_name=birth_names&where=&datasource_type=table&bar_stacked=false","csv_endpoint":"\/caravel\/explore\/table\/3\/?force=false&slice_name=Genders+by+State&row_limit=50000&show_legend=y&show_legend=false&groupby=state&granularity_sqla=ds&flt_op_1=not+in&flt_op_0=in&viz_type=dist_bar&since=100+years+ago&csv=true&until=now&collapsed_fieldsets=&datasource_id=3&y_axis_format=.3s&metrics=sum__sum_girls&metrics=sum__sum_boys&flt_eq_0=&flt_eq_1=other&flt_col_1=state&flt_col_0=gender&slice_id=16&previous_viz_type=dist_bar&having=&datasource_name=birth_names&where=&datasource_type=table&bar_stacked=false","standalone_endpoint":"\/caravel\/explore\/table\/3\/?force=false&slice_name=Genders+by+State&row_limit=50000&show_legend=y&show_legend=false&groupby=state&granularity_sqla=ds&flt_op_1=not+in&flt_op_0=in&viz_type=dist_bar&since=100+years+ago&until=now&collapsed_fieldsets=&datasource_id=3&y_axis_format=.3s&metrics=sum__sum_girls&metrics=sum__sum_boys&flt_eq_0=&flt_eq_1=other&flt_col_1=state&flt_col_0=gender&slice_id=16&standalone=true&previous_viz_type=dist_bar&having=&datasource_name=birth_names&where=&datasource_type=table&bar_stacked=false","is_cached":false,"cached_dttm":"2016-05-16T03:32:44","form_data":{"slice_name":"Genders by State","show_legend":true,"granularity_sqla":"ds","flt_op_5":"in","flt_op_4":"in","flt_op_7":"in","flt_op_6":"in","flt_op_1":"not in","flt_op_0":"in","flt_op_3":"in","flt_op_2":"in","flt_op_9":"in","flt_op_8":"in","json":"true","until":"now","columns":[],"y_axis_format":".3s","flt_col_7":"gender","flt_col_6":"gender","async":"","where":"","bar_stacked":false,"force":"false","row_limit":"50000","viz_type":"dist_bar","since":"100 years ago","collapsed_fieldsets":"","metrics":["sum__sum_girls","sum__sum_boys"],"flt_eq_8":"","flt_eq_9":"","flt_eq_6":"","flt_eq_7":"","flt_eq_4":"","flt_eq_5":"","flt_eq_2":"","flt_eq_3":"","flt_eq_0":"","flt_eq_1":"other","flt_col_1":"state","flt_col_0":"gender","flt_col_3":"gender","flt_col_2":"gender","flt_col_5":"gender","flt_col_4":"gender","slice_id":"16","standalone":"","flt_col_9":"gender","flt_col_8":"gender","previous_viz_type":"dist_bar","groupby":["state"],"extra_filters":"","having":""},"query":"SELECT state AS state,\n                SUM(sum_boys) AS sum__sum_boys,\n                SUM(sum_girls) AS sum__sum_girls\nFROM birth_names\nWHERE ds >= '1916-05-16 03:32:44.000000'\n  AND ds <= '2016-05-16 03:32:44.000000'\n  AND state NOT IN ('other')\nGROUP BY state\nORDER BY SUM(sum_girls) DESC LIMIT 50000\nOFFSET 0","cache_timeout":null,"data":[{"values":[{"y":5430796,"x":"CA"},{"y":3311985,"x":"TX"},{"y":3543961,"x":"NY"},{"y":2376385,"x":"OH"},{"y":2390275,"x":"PA"},{"y":2357411,"x":"IL"},{"y":1938321,"x":"MI"},{"y":1968060,"x":"FL"},{"y":1486126,"x":"NJ"},{"y":1285126,"x":"MA"}],"key":"sum__sum_boys"},{"values":[{"y":3567754,"x":"CA"},{"y":2313186,"x":"TX"},{"y":2280733,"x":"NY"},{"y":1622814,"x":"OH"},{"y":1615383,"x":"PA"},{"y":1614427,"x":"IL"},{"y":1326229,"x":"MI"},{"y":1312593,"x":"FL"},{"y":992702,"x":"NJ"},{"y":842146,"x":"MA"}],"key":"sum__sum_girls"}]}
# </urth-caravel-slice>
# Out:
# <urth-caravel-slice id="slice1">
# ...

# %% [markdown]
# Add three sliders to control limit, since, and until data in descriptor
# since date renders incorrectly, off by a decade (does this in the caravel application, too!)

# %%
# %%html
# <template id="t1" is="dom-bind">
# <urth-caravel-slice id="slice2">
# {
#  "json_endpoint": "/caravel/explore/table/2/?slice_name=Growth+Rate&row_limit=50000&metric=sum__SP_POP_TOTL&show_bubbles=y&entity=country_code&groupby=country_name&secondary_metric=sum__SP_POP_TOTL&viz_type=line&since=1960-01-01&json=true&until=2014-01-01&datasource_id=1&metrics=sum__SP_POP_TOTL&markup_type=markdown&country_fieldtype=cca3&granularity=year&slice_id=5&num_period_compare=10&datasource_type=table&compare_lag=10&limit=25&datasource_name=birth_names&where=&compare_suffix=o10Y",
#  "csv_endpoint": "/caravel/explore/table/2/?slice_name=Growth+Rate&row_limit=50000&metric=sum__SP_POP_TOTL&show_bubbles=y&entity=country_code&groupby=country_name&secondary_metric=sum__SP_POP_TOTL&viz_type=line&since=1960-01-01&csv=true&until=2014-01-01&datasource_id=1&metrics=sum__SP_POP_TOTL&markup_type=markdown&country_fieldtype=cca3&granularity=year&slice_id=5&num_period_compare=10&datasource_type=table&compare_lag=10&limit=25&datasource_name=birth_names&where=&compare_suffix=o10Y",
#  "standalone_endpoint": "/caravel/explore/table/2/?slice_name=Growth+Rate&row_limit=50000&metric=sum__SP_POP_TOTL&show_bubbles=y&entity=country_code&groupby=country_name&secondary_metric=sum__SP_POP_TOTL&viz_type=line&since=1960-01-01&until=2014-01-01&datasource_id=1&metrics=sum__SP_POP_TOTL&markup_type=markdown&country_fieldtype=cca3&granularity=year&slice_id=5&standalone=true&num_period_compare=10&datasource_type=table&compare_lag=10&limit=25&datasource_name=birth_names&where=&compare_suffix=o10Y",
#  "token": "token_034b4b7e",
#  "viz_name": "line",
#  "form_data": {
#   "slice_name": "Growth Rate",
#   "y_axis_zero": false,
#   "resample_fillmethod": "",
#   "line_interpolation": "linear",
#   "show_legend": true,
#   "granularity_sqla": "year",
#   "flt_op_5": "in",
#   "flt_op_4": "in",
#   "flt_op_7": "in",
#   "flt_op_6": "in",
#   "flt_op_1": "in",
#   "flt_op_0": "in",
#   "flt_op_3": "in",
#   "flt_op_2": "in",
#   "flt_op_9": "in",
#   "flt_op_8": "in",
#   "json": "false",
#   "until": "2014-01-01",
#   "y_axis_format": ".3s",
#   "slice_id": "5",
#   "resample_how": "",
#   "flt_col_6": "country_code",
#   "rich_tooltip": true,
#   "limit": "25",
#   "x_axis_format": "smart_date",
#   "async": null,
#   "where": "",
#   "force": null,
#   "show_brush": false,
#   "resample_rule": "",
#   "rolling_type": "None",
#   "viz_type": "line",
#   "since": "1970-01-01",
#   "time_compare": "",
#   "collapsed_fieldsets": null,
#   "rolling_periods": null,
#   "x_axis_showminmax": true,
#   "metrics": [
#    "sum__SP_POP_TOTL"
#   ],
#   "flt_eq_8": "",
#   "flt_eq_9": "",
#   "flt_eq_6": "",
#   "flt_eq_7": "",
#   "flt_eq_4": "",
#   "flt_eq_5": "",
#   "flt_eq_2": "",
#   "flt_eq_3": "",
#   "flt_eq_0": "",
#   "flt_eq_1": "",
#   "flt_col_1": "country_code",
#   "flt_col_0": "country_code",
#   "flt_col_3": "country_code",
#   "flt_col_2": "country_code",
#   "flt_col_5": "country_code",
#   "flt_col_4": "country_code",
#   "flt_col_7": "country_code",
#   "standalone": null,
#   "flt_col_9": "country_code",
#   "flt_col_8": "country_code",
#   "num_period_compare": 10,
#   "previous_viz_type": "line",
#   "having": "",
#   "y_log_scale": false,
#   "contribution": false,
#   "extra_filters": null,
#   "groupby": [
#    "country_name"
#   ]
#  }
# }
# </urth-caravel-slice>
#
# <span>limit: {{limit}}</span><paper-slider id="limit" value="{{limit}}" min=0 max="25"></paper-slider>
# <span>since: {{sinceDate}}</span><paper-slider id="since" value="{{since}}" min=0 max="1388534400000"></paper-slider>
# <span>until: {{untilDate}}</span><paper-slider id="until" value="{{until}}" min=0 max="1388534400000"></paper-slider>
#
# <script>
# t1.limit=25;
#
# limit.addEventListener('value-changed', function(value) {
#     var parser = document.createElement('a');
#     parser.href = slice2.slice.data.json_endpoint;
#     parser.search = "limit=" + t1.limit + "&" + parser.search;
#     slice2.slice.data.json_endpoint = parser.href;
#     console.log("new endpoint: "+parser.href.substring(1));
#     slice2.slice.render(true, slice2.root);
# });
#
# since.addEventListener('value-changed', function(value) {
#     t1.sinceDate = new Date(value.detail.value).toISOString().substring(0,10);
#     var parser = document.createElement('a');
#     parser.href = slice2.slice.data.json_endpoint;
#     parser.search = "since=" + t1.sinceDate + "&" + parser.search;
#     slice2.slice.data.json_endpoint = parser.href;
#     console.log("new endpoint: "+parser.href.substring(1));
#     slice2.slice.render(true, slice2.root);
# });
#
# until.addEventListener('value-changed', function(value) {
#     t1.untilDate = new Date(value.detail.value).toISOString().substring(0,10);
#     var parser = document.createElement('a');
#     parser.href = slice2.slice.data.json_endpoint;
#     parser.search = "until=" + t1.untilDate + "&" + parser.search;
#     slice2.slice.data.json_endpoint = parser.href;
#     console.log("new endpoint: "+parser.href.substring(1));
#     slice2.slice.render(true, slice2.root);
# });
# </script>
#
# </template>
# Out:
# <template id="t1" is="dom-bind">
# <urth-caravel-slice id="slice2">
# {
#  "json_endpoint": "/caravel/explore/table/2/?slice_name=Growth+Rate&row_limit=50000&metric=sum__SP_POP_TOTL&show_bubbles=y&entity=country_code&groupby=country_name&secondary_metric=sum__SP_POP_TOTL&viz_type=line&since=1960-01-01&json=true&until=2014-01-01&datasource_id=1&metrics=sum__SP_POP_TOTL&markup_type=markdown&country_fieldtype=cca3&granularity=year&slice_id=5&num_period_compare=10&datasource_type=table&compare_lag=10&limit=25&datasource_name=birth_names&where=&compare_suffix=o10Y",
# ...
